# %%
numbers = []

for i in range(5):
    num = float(input("Enter a number: "))
    numbers.append(num)


total = sum(numbers)
average = total / len(numbers)
maximum = max(numbers)
minimum = min(numbers)


print("Numbers:", numbers)
print("Sum:", total)
print("Average:", average)
print("Maximum:", maximum)
print("Minimum:", minimum)
# Out:
# Enter a number:  10
# Enter a number:  2
# Enter a number:  5
# Enter a number:  7
# Enter a number:  12
# Numbers: [10.0, 2.0, 5.0, 7.0, 12.0]
# Sum: 36.0
# Average: 7.2
# Maximum: 12.0
# Minimum: 2.0

# %%
words_list = []

for i in range(5):
    word = input("Enter a word: ")
    words_list.append(word)

words = tuple(words_list)


print("First word:", words[0])
print("Last word:", words[-1])
print("Total number of words:", len(words))


search_word = input("Enter a word to search: ")

if search_word in words:
    print("Word found in tuple.")
else:
    print("Word not found in tuple.")
# Out:
# Enter a word:  apple
# Enter a word:  cat
# Enter a word:  book
# Enter a word:  pen
# Enter a word:  egg
# First word: apple
# Last word: egg
# Total number of words: 5
# Enter a word to search:  pen
# Word found in tuple.

# %%
students = {}


for i in range(3):
    name = input("Enter student name: ")
    score = float(input("Enter student score: "))
    students[name] = score


print("Students and their scores:")
for name, score in students.items():
    print(name, ":", score)


highest_student = max(students, key=students.get)

print("Student with highest score:", highest_student)
print("Highest score:", students[highest_student])
# Out:
# Enter student name:  Afrah
# Enter student score:  100
# Enter student name:  Reema
# Enter student score:  80
# Enter student name:  Sara
# Enter student score:  75
# Students and their scores:
# Afrah : 100.0
# Reema : 80.0
# Sara : 75.0
# Student with highest score: Afrah
# Highest score: 100.0

# %%
list1 = list(map(int, input("Enter numbers for list 1 separated by spaces: ").split()))
list2 = list(map(int, input("Enter numbers for list 2 separated by spaces: ").split()))


set1 = set(list1)
set2 = set(list2)


print("Union:", set1.union(set2))
print("Intersection:", set1.intersection(set2))
print("Difference (set1 - set2):", set1.difference(set2))
# Out:
# Enter numbers for list 1 separated by spaces:  1 2 3 4
# Enter numbers for list 2 separated by spaces:  3 4 5 6
# Union: {1, 2, 3, 4, 5, 6}
# Intersection: {3, 4}
# Difference (set1 - set2): {1, 2}

# %%
names = []

for i in range(5):
    name = input("Enter a name: ")
    names.append(name)


names_tuple = tuple(names)
print("Tuple:", names_tuple)


name_dict = {}

for name in names:
    name_dict[name] = len(name)

print("Dictionary (name:length):", name_dict)


length_set = set(name_dict.values())

print("Set of unique name lengths:", length_set)
# Out:
# Enter a name:  Afrah
# Enter a name:  Sara
# Enter a name:  Reema
# Enter a name:  Lina
# Enter a name:  Noor
# Tuple: ('Afrah', 'Sara', 'Reema', 'Lina', 'Noor')
# Dictionary (name:length): {'Afrah': 5, 'Sara': 4, 'Reema': 5, 'Lina': 4, 'Noor': 4}
# Set of unique name lengths: {4, 5}
