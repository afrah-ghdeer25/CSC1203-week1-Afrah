# %%
import math


radius = float(input("Enter the radius of the circle: "))


def calculate_area(r):
    return math.pi * (r ** 2)


calculate_circumference = lambda r: 2 * math.pi * r


area = calculate_area(radius)
circumference = calculate_circumference(radius)


area = round(area, 2)
circumference = round(circumference, 2)


print("Area:", area)
print("Circumference:", circumference)
# Out:
# Enter the radius of the circle:  15
# Area: 706.86
# Circumference: 94.25

# %%
import re


text = input("Enter a string: ")


numbers = re.findall(r'\d+', text)


numbers = list(map(int, numbers))


def calculate_sum(nums):
    return sum(nums)


double_value = lambda x: x * 2


total_sum = calculate_sum(numbers)
doubled = double_value(total_sum)


print("Numbers found:", numbers)
print("Sum:", total_sum)
print("Doubled value:", doubled)
# Out:
# Enter a string:  I have 2 pen and 4 note
# Numbers found: [2, 4]
# Sum: 6
# Doubled value: 12

# %%
import math


user_input = input("Enter numbers separated by commas: ")


numbers = list(map(float, user_input.split(',')))

def calculate_squares(nums):
    square = lambda x: x ** 2
    return list(map(square, nums))

squares = calculate_squares(numbers)


max_square = max(squares)
sqrt_sum_squares = math.sqrt(sum(squares))


print("Original numbers:", numbers)
print("Squares:", squares)
print("Maximum square:", max_square)
print("Square root of sum of squares:", sqrt_sum_squares)
# Out:
# Enter numbers separated by commas:  1,2,5
# Original numbers: [1.0, 2.0, 5.0]
# Squares: [1.0, 4.0, 25.0]
# Maximum square: 25.0
# Square root of sum of squares: 5.477225575051661

# %%
import re
import math


password = input("Enter a password: ")


has_upper = re.search(r'[A-Z]', password)
has_lower = re.search(r'[a-z]', password)
has_digit = re.search(r'\d', password)


if has_upper and has_lower and has_digit:
    strength = "Strong"
else:
    strength = "Weak"


scores_input = input("Enter 5 scores separated by spaces: ")
scores = list(map(float, scores_input.split()))


def calculate_average(nums):
    return sum(nums) / len(nums)


avg_lambda = lambda nums: sum(nums) / len(nums)

average = avg_lambda(scores)


rounded_average = math.ceil(average)


print("Password strength:", strength)
print("Rounded average score:", rounded_average)
# Out:
# Enter a password:  Aa52@
# Enter 5 scores separated by spaces:  10 20 30 50 70
# Password strength: Strong
# Rounded average score: 36

# %%
import re
import math


paragraph = input("Enter a paragraph: ")


vowel_words = re.findall(r'\b[AEIOUaeiou]\w*', paragraph)


def count_vowels(text):
    return len(re.findall(r'[AEIOUaeiou]', text))

total_vowels = count_vowels(paragraph)


word_length = lambda word: len(word)
lengths = list(map(word_length, vowel_words))


if lengths:
    average_length = round(sum(lengths) / len(lengths), 2)
else:
    average_length = 0.00


print("Words starting with vowels:", vowel_words)
print("Total vowels:", total_vowels)
print("Average vowel-word length:", average_length)
# Out:
# Enter a paragraph:  Apple is orange
# Words starting with vowels: ['Apple', 'is', 'orange']
# Total vowels: 6
# Average vowel-word length: 4.33
